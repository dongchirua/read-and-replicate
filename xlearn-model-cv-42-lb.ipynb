# %%
import os
import json
from operator import itemgetter
from collections import defaultdict
from functools import partial
from math import isnan

import cv2
import dill
import numpy as np
import pandas as pd
import scipy as sp
from tqdm import tqdm
from joblib import Parallel, delayed

from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import LabelEncoder

import xlearn as xl

# %%
train_df = pd.read_csv("/data/quy/petfinder-adoption-prediction/train.csv", encoding="utf-8")
test_df = pd.read_csv("/data/quy/petfinder-adoption-prediction/test.csv", encoding="utf-8")

smpsb_df = pd.read_csv("/data/quy/petfinder-adoption-prediction/sample_submission.csv")

if os.dir.ex
os.mkdir("./working")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-26-2034ae24412a> in <module>
#       4 smpsb_df = pd.read_csv("/data/quy/petfinder-adoption-prediction/sample_submission.csv")
#       5
# ----> 6 os.mkdir("./working")
#
# FileExistsError: [Errno 17] File exists: './working'

# %%
train_df["group"] = 0
petid_map = {v: i for i, v in enumerate(pd.concat([train_df["PetID"], test_df["PetID"]]))}
rescuerid_encoder = LabelEncoder().fit(pd.concat([train_df["RescuerID"], test_df["RescuerID"]]))

for group, (_, group_idx) in enumerate(GroupKFold(n_splits=10).split(train_df,
                                                                     train_df["AdoptionSpeed"],
                                                                     rescuerid_encoder.transform(train_df["RescuerID"]))):
    train_df.loc[group_idx, "group"] = group

# %%
train_df.pivot_table(columns="AdoptionSpeed",
                     index="group",
                     values="Breed1",
                     aggfunc="count")
# Out:
# AdoptionSpeed   0    1    2    3    4
# group
# 0              52  253  425  415  355
# 1              34  304  397  336  429
# 2              37  282  439  338  404
# 3              37  322  366  350  424
# 4              32  284  372  329  482
# 5              33  314  398  338  416
# 6              41  379  385  280  414
# 7              50  283  453  291  422
# 8              51  357  387  272  432
# 9              43  312  415  310  419

# %%
class FFMformatter():
    def __init__(self,
                 numerical_field_max: int,
                 key_column="PetID"
                 ):
        
        self.numerical_field_max = numerical_field_max
        self.key_column = key_column

        self.numerical_field_last = -1
        self.numerical_field = defaultdict(lambda: self.new_numerical_field())
        self.field_nan = defaultdict(lambda: np.NaN)
        
        self.categorical_field_last = numerical_field_max
        self.categorical_feature_last = numerical_field_max
        self.categorical_field = defaultdict(lambda: self.new_categorical_field())
        self.categorical_feature = defaultdict(lambda: defaultdict(lambda: self.new_categorical_feature()))
        self.result = {}
        self.categorical_columns = set()


    def add_dataframe(self, df: pd.DataFrame):
        petids = df[self.key_column]
        for field in df.columns:
            if field == self.key_column:
                continue
            for petid, value in zip(petids, df[field]):
                if self.field_nan[field] == value or ((type(value) == float) and isnan(value)):
                    continue

                if field in self.categorical_columns:
                    field_id = self.categorical_field[field]
                    self.result[petid] += " {}:{}:1".format(field_id,
                                                            self.categorical_feature[field_id][value])
                
                else:
                    field_id = self.numerical_field[field]
                    self.result[petid] += " {}:{}:{}".format(field_id,
                                                             field_id,
                                                             value)

    def add_field_dataframe(self, df, field_col, value_col):
        field_id = self.categorical_field[field_col]
        for _, row in tqdm(df.iterrows()):
            petid = row[self.key_column]
            self.result[petid] += " {}:{}:{}".format(field_id,
                                                     self.categorical_feature[field_id][row[field_col]],
                                                     row[value_col])
        
    def add_dataframe_as_samefield(self, df, basecol=None):
        assert self.key_column in df.columns
        cols = [col for col in df.columns if col != self.key_column]
        if basecol is None:
            basecol = cols[0]
        field_id = self.categorical_field[basecol]
        key_vals = df[self.key_column].values
        for col in cols:
            for key_val, value in zip(key_vals, df[col].values):
                if self.field_nan[basecol] == value or ((type(value) == float) and isnan(value)):
                    continue
                self.result[key_val] += " {}:{}:{}".format(field_id,
                                                           self.categorical_feature[field_id][col],
                                                           value)


    def set_categorical_columns(self, columns):
        if type(columns) == str:
            self.categorical_columns.add(columns)
        else:
            self.categorical_columns.update(columns)


    def set_multicolumns_as_column(self, columns):
        self.set_categorical_columns(columns)
        base_field = self.categorical_field[columns[0]]
        for col in columns:
            self.categorical_field[col] = base_field


    def add_Petids(self, keys, targets=None):
        if targets is not None:
            for key, target in zip(keys, targets):
                self.result[key] = str(target)
        else:
            for key in keys:
                self.result[key] = "-1"

    def set_field_nanvalue(self, col, nanvalue=np.NaN):
        self.field_nan[col] = nanvalue

    def new_numerical_field(self):
        self.numerical_field_last += 1
        if self.numerical_field_last > self.numerical_field_max:
            raise
        return self.numerical_field_last * 1

    def new_categorical_field(self):
        self.categorical_field_last += 1
        return self.categorical_field_last * 1
    
    def new_categorical_feature(self):
        self.categorical_feature_last += 1
        return self.categorical_feature_last * 1

# %%
df2ffm = FFMformatter(numerical_field_max=200)

df2ffm.add_Petids(train_df["PetID"].values, train_df["AdoptionSpeed"].values)
df2ffm.add_Petids(test_df["PetID"].values)

# %% [markdown]
# # tabular data

# %%
train_df["care_count"] = (train_df["Vaccinated"] == 1).astype(np.uint8) + (train_df["Dewormed"] == 1) + (train_df["Sterilized"] == 1)
test_df["care_count"] = (test_df["Vaccinated"] == 1).astype(np.uint8) + (test_df["Dewormed"] == 1) + (test_df["Sterilized"] == 1)

train_df["care_uncertain_count"] = ((train_df["Vaccinated"] == 3).astype(np.uint8) +
                                    (train_df["Dewormed"] == 3) +
                                    (train_df["Sterilized"] == 3))
test_df["care_uncertain_count"] = ((test_df["Vaccinated"] == 3).astype(np.uint8) +
                                   (test_df["Dewormed"] == 3) +
                                   (test_df["Sterilized"] == 3))

train_df["color_counts"] = 3 - (train_df.filter(regex="^Color") == 0).sum(axis=1)
test_df["color_counts"] = 3 - (test_df.filter(regex="^Color") == 0).sum(axis=1)

rescuer_count_map = pd.concat([train_df["RescuerID"], test_df["RescuerID"]]).value_counts().to_dict()
train_df["Rescuer_count"] = np.log(train_df["RescuerID"].map(rescuer_count_map))
test_df["Rescuer_count"] = np.log(test_df["RescuerID"].map(rescuer_count_map))

train_df["Fee"] = np.log1p(train_df["Fee"])
test_df["Fee"] = np.log1p(test_df["Fee"])

train_df["Age"] = np.log1p(train_df["Age"])
test_df["Age"] = np.log1p(test_df["Age"])

train_df["description_len"] = np.log1p(train_df["Description"].fillna("").str.len())
test_df["description_len"] = np.log1p(test_df["Description"].fillna("").str.len())

train_df["name_len"] = np.log1p(train_df["Name"].fillna("").str.len())
test_df["name_len"] = np.log1p(test_df["Name"].fillna("").str.len())

# https://www.kaggle.com/c/petfinder-adoption-prediction/discussion/78040

# state GDP: https://en.wikipedia.org/wiki/List_of_Malaysian_states_by_GDP
state_gdp = {
    41336: 116.679,
    41325: 40.596,
    41367: 23.02,
    41401: 190.075,
    41415: 5.984,
    41324: 37.274,
    41332: 42.389,
    41335: 52.452,
    41330: 67.629,
    41380: 5.642,
    41327: 81.284,
    41345: 80.167,
    41342: 121.414,
    41326: 280.698,
    41361: 32.270
}

# state population: https://en.wikipedia.org/wiki/Malaysia
state_population = {
    41336: 33.48283,
    41325: 19.47651,
    41367: 15.39601,
    41401: 16.74621,
    41415: 0.86908,
    41324: 8.21110,
    41332: 10.21064,
    41335: 15.00817,
    41330: 23.52743,
    41380: 2.31541,
    41327: 15.61383,
    41345: 32.06742,
    41342: 24.71140,
    41326: 54.62141,
    41361: 10.35977
}

train_df["state_gdp"] = train_df.State.map(state_gdp)
test_df["state_gdp"] = test_df.State.map(state_gdp)

train_df["state_population"] = train_df.State.map(state_population)
test_df["state_population"] = test_df.State.map(state_population)

for col in ["description_len", "name_len", "state_gdp", "state_population", "Rescuer_count", "Fee", "Age"]:
    mean, std = train_df[col].mean(), train_df[col].std()
    train_df[col] = (train_df[col] - mean)/std
    test_df[col] = (test_df[col] - mean)/std

# %%
train_df.head()
# Out:
#    Type         Name       Age  Breed1  Breed2  Gender  Color1  Color2  \
# 0     2       Nibble -0.390818     299       0       1       1       7
# 1     2  No Name Yet -1.070282     265       0       1       1       2
# 2     1       Brisco -1.070282     307       0       1       2       7
# 3     1         Miko -0.172080     307       0       2       1       2
# 4     1       Hunter -1.070282     307       0       1       1       0
#
#    Color3  MaturitySize  ...  AdoptionSpeed  group  care_count  \
# 0       0             1  ...              2      7           0
# 1       0             2  ...              0      3           0
# 2       0             2  ...              3      0           2
# 3       0             2  ...              2      6           2
# 4       0             2  ...              2      5           0
#
#    care_uncertain_count  color_counts  Rescuer_count  description_len  \
# 0                     0             2       0.033127         0.499203
# 1                     3             2      -1.111528        -0.524061
# 2                     0             2       2.262287         0.582625
# 3                     0             2       1.041896        -0.328732
# 4                     0             1       1.584551         0.575560
#
#    name_len state_gdp  state_population
# 0 -0.055035  0.739540          0.833461
# 1  0.609470 -0.447795         -1.225197
# 2 -0.055035  0.739540          0.833461
# 3 -0.469857 -0.447795         -1.225197
# 4 -0.055035  0.739540          0.833461
#
# [5 rows x 33 columns]

# %%
df2ffm.set_multicolumns_as_column(["Color1", "Color2", "Color3"])
df2ffm.set_multicolumns_as_column(["Breed1", "Breed2"])
df2ffm.set_categorical_columns(["Gender", "State"])

for col in ["Color1", "Color2", "Color3", "Breed1", "Breed2", "FurLength", "MaturitySize", "Health", "State"]:
    df2ffm.set_field_nanvalue(col, 0)

for col in ["Vacciated", "Dewormed", "Sterilized"]:
    df2ffm.set_field_nanvalue(col, 3)

drop_col = ["Name", "Description", "RescuerID"]
df2ffm.add_dataframe(train_df.drop(drop_col + ["AdoptionSpeed", "group"], axis=1))
df2ffm.add_dataframe(test_df.drop(drop_col, axis=1))

# %% [markdown]
# # metadata

# %%
def load_metadata(path):
    file = path.split("/")[-1]
    pet_id = file[:-5].split("-")[0]
    file_id = file[:-5].split("-")[1]
    
    with open(path, encoding="utf-8") as f:
        jfile = json.loads(f.read())
    response = {"labels": [],
                "text": {"PetID": pet_id,
                         "FileID": file_id,
                         "description": ""}}
    
    if "labelAnnotations" in jfile.keys():
        for anot in jfile["labelAnnotations"]:
            response["labels"].append({"PetID": pet_id,
                                       "FileID": file_id,
                                       "description": anot["description"],
                                       "score": anot["score"]})

    if "imagePropertiesAnnotation" in jfile.keys():
        colors = np.zeros((10, 1, 3), dtype=np.uint8)
        scores = np.zeros(10)
        fractions = np.zeros(10)
        getscore = itemgetter("score")
        for i, color in enumerate(sorted(jfile['imagePropertiesAnnotation']["dominantColors"]["colors"],
                                         key=getscore,
                                         reverse=True)
                                 ):

            for j, c in enumerate(["red", "green", "blue"]):
                if not color["color"].get(c) is None:
                    colors[i, 0, j] = color["color"][c] 
                
            scores[i] = color["score"]
            fractions[i] = color["pixelFraction"]
        hsv = cv2.cvtColor(colors, cv2.COLOR_RGB2HSV_FULL)
        response["property"] = {"PetID": pet_id,
                                "FileID": file_id,
                                "top_red": colors[0, 0, 0],
                                "top_green": colors[0, 0, 1],
                                "top_blue": colors[0, 0, 2],
                                "top_score": scores[0],
                                "top_fraction": fractions[0],
                                "top_hue": hsv[0, 0, 0],
                                "top_saturation": hsv[0, 0, 1],
                                "top_brightness": hsv[0, 0, 2],
                                "top3_score": scores[:3].sum(),
                                "top3_fraction": fractions[:3].sum(),
                                "top3_area": np.linalg.norm(np.cross((colors[1] - colors[0])[0], (colors[2] - colors[0])[0])),
                                "top10_fraction": fractions.sum(),
                                "top10_score": scores.sum()}

    if 'cropHintsAnnotation' in jfile.keys():
        tmp = jfile["cropHintsAnnotation"]["cropHints"][0]
        response["crop"] = {"PetID": pet_id,
                            "FileID": file_id,
                            "confidence": tmp["confidence"]}
        if not tmp.get("importanceFraction") is None:
            response["crop"]["importanceFraction"] = tmp["importanceFraction"]
    
    if 'textAnnotations' in jfile.keys():
        for anot in jfile["textAnnotations"]:
            response["text"]["description"] += anot["description"] + " "
    
    if "faceAnnotations" in jfile.keys():
        faceanot = jfile["faceAnnotations"][0]
        response["face"] = {"PetID": pet_id,
                            "FileID": file_id,
                            "detectionConfidence": faceanot['detectionConfidence'],
                            'landmarkingConfidence': faceanot['landmarkingConfidence'],
                            }
    
    return response

# %%
metadata_path = [dir_ + file for dir_ in ["/data/quy/petfinder-adoption-prediction/train_meta/",
                                          "/data/quy/petfinder-adoption-prediction/test_meta/"]
                                 for file in os.listdir(dir_)]

print(len(metadata_path))
# Out:
# 72776

# %%
results = Parallel(n_jobs=-1, verbose=50)([delayed(load_metadata)(path) for path in metadata_path])

labels = []
properties = []
crops = []
faces = []
texts = []
for res in tqdm(results):
    if not res.get("labels") is None:
        labels.extend(res["labels"])
    if not res.get("property") is None:
        properties.append(res["property"])
    if not res.get("crop") is None:
        crops.append(res["crop"])
    if not res.get("face") is None:
        faces.append(res["face"])
    if not res.get("text") is None:
        texts.append(res["text"])

labels_df = pd.DataFrame(labels)
properties_df = pd.DataFrame(properties)
crops_df = pd.DataFrame(crops)
faces_df = pd.DataFrame(faces)
texts_df = pd.DataFrame(texts)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1987s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.0871s.) Setting batch_size=8.
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  87 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  91 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  95 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  99 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 101 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 103 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 107 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 115 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.0943s.) Setting batch_size=32.
# [Parallel(n_jobs=-1)]: Done 123 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 131 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 139 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 141 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 149 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 157 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 165 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 181 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 189 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 197 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 221 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 229 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 231 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 239 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 247 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 255 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 263 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 271 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 279 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 287 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 295 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 303 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 311 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 319 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 327 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 335 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 343 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 351 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 383 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1120s.) Setting batch_size=114.
# [Parallel(n_jobs=-1)]: Done 415 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 447 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 479 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 511 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 543 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 575 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 607 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 639 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 671 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 703 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 735 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 767 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 799 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 831 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 863 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 895 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 927 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 959 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 991 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 1023 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 1055 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 1087 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 1119 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 1151 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 1183 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 1215 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 1247 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 1279 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 1311 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 1343 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 1375 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 1489 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1889s.) Setting batch_size=240.
# [Parallel(n_jobs=-1)]: Done 1603 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 1717 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 1831 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 1945 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 2059 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 2173 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 2287 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 2401 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 2515 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 2629 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 2743 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 2857 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 2971 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 3085 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 3199 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 3313 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 3427 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 3541 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 3655 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 3769 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 3883 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 3997 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 4111 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 4225 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 4339 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 4453 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 4567 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 4681 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 4795 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 4909 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 5023 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 5263 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 5503 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 5743 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=-1)]: Done 5983 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=-1)]: Done 6223 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=-1)]: Done 6463 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=-1)]: Done 6703 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done 6943 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done 7183 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done 7423 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done 7663 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done 7903 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done 8143 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done 8383 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 8623 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 8863 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 9103 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 9343 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done 9583 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done 9823 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done 10063 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done 10303 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done 10543 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done 10783 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 11023 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 11263 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 11503 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 11743 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 11983 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 12223 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 12463 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done 12703 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done 12943 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done 13183 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done 13423 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done 13663 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done 13903 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done 14143 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done 14383 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done 14623 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done 14863 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 15103 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 15343 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 15583 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 15823 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 16063 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done 16303 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done 16543 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done 16783 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done 17023 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done 17263 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 17503 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 17743 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 17983 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 18223 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 18463 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 18703 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 18943 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 19183 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 19423 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 19663 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 19903 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 20143 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 20383 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done 20623 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done 20863 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done 21103 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done 21343 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done 21583 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done 21823 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done 22063 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done 22303 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done 22543 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done 22783 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done 23023 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done 23263 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done 23503 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done 23743 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done 23983 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done 24223 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done 24463 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done 24703 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done 24943 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done 25183 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done 25423 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=-1)]: Done 25663 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.2674s.) Setting batch_size=120.
# [Parallel(n_jobs=-1)]: Done 25903 tasks      | elapsed:    9.4s
# [Parallel(n_jobs=-1)]: Done 26143 tasks      | elapsed:    9.4s
# [Parallel(n_jobs=-1)]: Done 26383 tasks      | elapsed:    9.5s
# [Parallel(n_jobs=-1)]: Done 26623 tasks      | elapsed:    9.5s
# [Parallel(n_jobs=-1)]: Done 26863 tasks      | elapsed:    9.5s
# [Parallel(n_jobs=-1)]: Done 27103 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=-1)]: Done 27343 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=-1)]: Done 27583 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=-1)]: Done 27823 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=-1)]: Done 28063 tasks      | elapsed:   10.3s
# [Parallel(n_jobs=-1)]: Done 28303 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=-1)]: Done 28543 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=-1)]: Done 28783 tasks      | elapsed:   11.2s
# [Parallel(n_jobs=-1)]: Done 29023 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-1)]: Done 29263 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=-1)]: Done 29503 tasks      | elapsed:   16.2s
# [Parallel(n_jobs=-1)]: Done 29743 tasks      | elapsed:   16.7s
# [Parallel(n_jobs=-1)]: Done 29983 tasks      | elapsed:   16.8s
# [Parallel(n_jobs=-1)]: Done 30223 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=-1)]: Done 30463 tasks      | elapsed:   17.1s
# [Parallel(n_jobs=-1)]: Done 30703 tasks      | elapsed:   17.2s
# [Parallel(n_jobs=-1)]: Done 30943 tasks      | elapsed:   17.2s
# [Parallel(n_jobs=-1)]: Done 31183 tasks      | elapsed:   17.4s
# [Parallel(n_jobs=-1)]: Done 31423 tasks      | elapsed:   17.6s
# [Parallel(n_jobs=-1)]: Done 31663 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-1)]: Done 31903 tasks      | elapsed:   18.1s
# [Parallel(n_jobs=-1)]: Done 32143 tasks      | elapsed:   18.6s
# [Parallel(n_jobs=-1)]: Done 32383 tasks      | elapsed:   18.8s
# [Parallel(n_jobs=-1)]: Done 32503 tasks      | elapsed:   19.1s
# [Parallel(n_jobs=-1)]: Batch computation too slow (9.7870s.) Setting batch_size=60.
# [Parallel(n_jobs=-1)]: Done 32743 tasks      | elapsed:   19.1s
# [Parallel(n_jobs=-1)]: Done 32863 tasks      | elapsed:   19.2s
# [Parallel(n_jobs=-1)]: Done 33103 tasks      | elapsed:   19.3s
# [Parallel(n_jobs=-1)]: Done 33223 tasks      | elapsed:   19.5s
# [Parallel(n_jobs=-1)]: Done 33343 tasks      | elapsed:   19.9s
# [Parallel(n_jobs=-1)]: Done 33463 tasks      | elapsed:   19.9s
# [Parallel(n_jobs=-1)]: Done 33583 tasks      | elapsed:   20.0s
# [Parallel(n_jobs=-1)]: Done 33703 tasks      | elapsed:   20.2s
# [Parallel(n_jobs=-1)]: Done 33823 tasks      | elapsed:   20.4s
# [Parallel(n_jobs=-1)]: Done 33943 tasks      | elapsed:   20.8s
# [Parallel(n_jobs=-1)]: Done 34183 tasks      | elapsed:   20.8s
# [Parallel(n_jobs=-1)]: Done 34303 tasks      | elapsed:   20.8s
# [Parallel(n_jobs=-1)]: Done 34423 tasks      | elapsed:   21.1s
# [Parallel(n_jobs=-1)]: Done 34543 tasks      | elapsed:   21.3s
# [Parallel(n_jobs=-1)]: Done 34663 tasks      | elapsed:   21.6s
# [Parallel(n_jobs=-1)]: Done 34783 tasks      | elapsed:   21.8s
# [Parallel(n_jobs=-1)]: Done 34903 tasks      | elapsed:   21.9s
# [Parallel(n_jobs=-1)]: Done 35023 tasks      | elapsed:   22.0s
# [Parallel(n_jobs=-1)]: Done 35143 tasks      | elapsed:   22.0s
# [Parallel(n_jobs=-1)]: Done 35263 tasks      | elapsed:   22.3s
# [Parallel(n_jobs=-1)]: Done 35383 tasks      | elapsed:   22.4s
# [Parallel(n_jobs=-1)]: Done 35503 tasks      | elapsed:   22.7s
# [Parallel(n_jobs=-1)]: Done 35623 tasks      | elapsed:   22.7s
# [Parallel(n_jobs=-1)]: Done 35743 tasks      | elapsed:   23.0s
# [Parallel(n_jobs=-1)]: Done 35863 tasks      | elapsed:   23.3s
# [Parallel(n_jobs=-1)]: Done 35923 tasks      | elapsed:   23.4s
# [Parallel(n_jobs=-1)]: Batch computation too slow (4.3615s.) Setting batch_size=30.
# [Parallel(n_jobs=-1)]: Done 35983 tasks      | elapsed:   23.5s
# [Parallel(n_jobs=-1)]: Done 36043 tasks      | elapsed:   23.5s
# [Parallel(n_jobs=-1)]: Done 36103 tasks      | elapsed:   23.5s
# [Parallel(n_jobs=-1)]: Done 36223 tasks      | elapsed:   23.8s
# [Parallel(n_jobs=-1)]: Done 36283 tasks      | elapsed:   23.9s
# [Parallel(n_jobs=-1)]: Done 36403 tasks      | elapsed:   24.0s
# [Parallel(n_jobs=-1)]: Done 36523 tasks      | elapsed:   24.0s
# [Parallel(n_jobs=-1)]: Done 36643 tasks      | elapsed:   24.1s
# [Parallel(n_jobs=-1)]: Done 36703 tasks      | elapsed:   24.1s
# [Parallel(n_jobs=-1)]: Done 36763 tasks      | elapsed:   24.1s
# [Parallel(n_jobs=-1)]: Done 36883 tasks      | elapsed:   24.2s
# [Parallel(n_jobs=-1)]: Done 36943 tasks      | elapsed:   24.4s
# [Parallel(n_jobs=-1)]: Done 37003 tasks      | elapsed:   24.5s
# [Parallel(n_jobs=-1)]: Done 37123 tasks      | elapsed:   24.6s
# [Parallel(n_jobs=-1)]: Done 37183 tasks      | elapsed:   24.7s
# [Parallel(n_jobs=-1)]: Done 37243 tasks      | elapsed:   24.8s
# [Parallel(n_jobs=-1)]: Done 37303 tasks      | elapsed:   24.8s
# [Parallel(n_jobs=-1)]: Done 37363 tasks      | elapsed:   24.8s
# [Parallel(n_jobs=-1)]: Done 37423 tasks      | elapsed:   24.9s
# [Parallel(n_jobs=-1)]: Done 37483 tasks      | elapsed:   25.2s
# [Parallel(n_jobs=-1)]: Done 37543 tasks      | elapsed:   25.2s
# [Parallel(n_jobs=-1)]: Done 37573 tasks      | elapsed:   25.3s
# [Parallel(n_jobs=-1)]: Done 37603 tasks      | elapsed:   25.5s
# [Parallel(n_jobs=-1)]: Done 37633 tasks      | elapsed:   25.5s
# [Parallel(n_jobs=-1)]: Done 37693 tasks      | elapsed:   25.5s
# [Parallel(n_jobs=-1)]: Done 37753 tasks      | elapsed:   25.5s
# [Parallel(n_jobs=-1)]: Done 37813 tasks      | elapsed:   25.5s
# [Parallel(n_jobs=-1)]: Done 37873 tasks      | elapsed:   25.6s
# [Parallel(n_jobs=-1)]: Done 37903 tasks      | elapsed:   25.7s
# [Parallel(n_jobs=-1)]: Done 37963 tasks      | elapsed:   25.7s
# [Parallel(n_jobs=-1)]: Done 38023 tasks      | elapsed:   25.8s
# [Parallel(n_jobs=-1)]: Done 38083 tasks      | elapsed:   25.8s
# [Parallel(n_jobs=-1)]: Done 38113 tasks      | elapsed:   25.9s
# [Parallel(n_jobs=-1)]: Done 38173 tasks      | elapsed:   25.9s
# [Parallel(n_jobs=-1)]: Done 38233 tasks      | elapsed:   25.9s
# [Parallel(n_jobs=-1)]: Done 38263 tasks      | elapsed:   26.0s
# [Parallel(n_jobs=-1)]: Done 38293 tasks      | elapsed:   26.2s
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.0204s.) Setting batch_size=15.
# [Parallel(n_jobs=-1)]: Done 38323 tasks      | elapsed:   26.2s
# [Parallel(n_jobs=-1)]: Done 38353 tasks      | elapsed:   26.2s
# [Parallel(n_jobs=-1)]: Done 38383 tasks      | elapsed:   26.2s
# [Parallel(n_jobs=-1)]: Done 38413 tasks      | elapsed:   26.2s
# [Parallel(n_jobs=-1)]: Done 38443 tasks      | elapsed:   26.3s
# [Parallel(n_jobs=-1)]: Done 38473 tasks      | elapsed:   26.3s
# [Parallel(n_jobs=-1)]: Done 38503 tasks      | elapsed:   26.3s
# [Parallel(n_jobs=-1)]: Done 38533 tasks      | elapsed:   26.4s
# [Parallel(n_jobs=-1)]: Done 38563 tasks      | elapsed:   26.4s
# [Parallel(n_jobs=-1)]: Done 38593 tasks      | elapsed:   26.5s
# [Parallel(n_jobs=-1)]: Done 38653 tasks      | elapsed:   26.5s
# [Parallel(n_jobs=-1)]: Done 38683 tasks      | elapsed:   26.5s
# [Parallel(n_jobs=-1)]: Done 38713 tasks      | elapsed:   26.6s
# [Parallel(n_jobs=-1)]: Done 38743 tasks      | elapsed:   26.6s
# [Parallel(n_jobs=-1)]: Done 38773 tasks      | elapsed:   26.7s
# [Parallel(n_jobs=-1)]: Done 38803 tasks      | elapsed:   26.7s
# [Parallel(n_jobs=-1)]: Done 38833 tasks      | elapsed:   26.8s
# [Parallel(n_jobs=-1)]: Done 38863 tasks      | elapsed:   26.9s
# [Parallel(n_jobs=-1)]: Done 38893 tasks      | elapsed:   26.9s
# [Parallel(n_jobs=-1)]: Done 38908 tasks      | elapsed:   26.9s
# [Parallel(n_jobs=-1)]: Done 38938 tasks      | elapsed:   27.0s
# [Parallel(n_jobs=-1)]: Done 38968 tasks      | elapsed:   27.0s
# [Parallel(n_jobs=-1)]: Done 38998 tasks      | elapsed:   27.0s
# [Parallel(n_jobs=-1)]: Done 39028 tasks      | elapsed:   27.0s
# [Parallel(n_jobs=-1)]: Done 39043 tasks      | elapsed:   27.1s
# [Parallel(n_jobs=-1)]: Done 39073 tasks      | elapsed:   27.1s
# [Parallel(n_jobs=-1)]: Done 39088 tasks      | elapsed:   27.1s
# [Parallel(n_jobs=-1)]: Done 39118 tasks      | elapsed:   27.2s
# [Parallel(n_jobs=-1)]: Done 39148 tasks      | elapsed:   27.2s
# [Parallel(n_jobs=-1)]: Done 39163 tasks      | elapsed:   27.2s
# [Parallel(n_jobs=-1)]: Done 39193 tasks      | elapsed:   27.2s
# [Parallel(n_jobs=-1)]: Done 39208 tasks      | elapsed:   27.3s
# [Parallel(n_jobs=-1)]: Done 39238 tasks      | elapsed:   27.3s
# [Parallel(n_jobs=-1)]: Done 39268 tasks      | elapsed:   27.3s
# [Parallel(n_jobs=-1)]: Done 39283 tasks      | elapsed:   27.3s
# [Parallel(n_jobs=-1)]: Done 39298 tasks      | elapsed:   27.3s
# [Parallel(n_jobs=-1)]: Done 39313 tasks      | elapsed:   27.4s
# [Parallel(n_jobs=-1)]: Done 39328 tasks      | elapsed:   27.4s
# [Parallel(n_jobs=-1)]: Done 39343 tasks      | elapsed:   27.4s
# [Parallel(n_jobs=-1)]: Done 39358 tasks      | elapsed:   27.4s
# [Parallel(n_jobs=-1)]: Done 39373 tasks      | elapsed:   27.4s
# [Parallel(n_jobs=-1)]: Done 39388 tasks      | elapsed:   27.4s
# [Parallel(n_jobs=-1)]: Done 39403 tasks      | elapsed:   27.5s
# [Parallel(n_jobs=-1)]: Done 39433 tasks      | elapsed:   27.5s
# [Parallel(n_jobs=-1)]: Done 39448 tasks      | elapsed:   27.5s
# [Parallel(n_jobs=-1)]: Done 39463 tasks      | elapsed:   27.5s
# [Parallel(n_jobs=-1)]: Done 39478 tasks      | elapsed:   27.6s
# [Parallel(n_jobs=-1)]: Done 39493 tasks      | elapsed:   27.6s
# [Parallel(n_jobs=-1)]: Done 39508 tasks      | elapsed:   27.7s
# [Parallel(n_jobs=-1)]: Done 39523 tasks      | elapsed:   27.7s
# [Parallel(n_jobs=-1)]: Done 39553 tasks      | elapsed:   27.7s
# [Parallel(n_jobs=-1)]: Done 39568 tasks      | elapsed:   27.7s
# [Parallel(n_jobs=-1)]: Done 39583 tasks      | elapsed:   27.8s
# [Parallel(n_jobs=-1)]: Done 39598 tasks      | elapsed:   27.8s
# [Parallel(n_jobs=-1)]: Done 39613 tasks      | elapsed:   27.8s
# [Parallel(n_jobs=-1)]: Done 39628 tasks      | elapsed:   27.8s
# [Parallel(n_jobs=-1)]: Done 39643 tasks      | elapsed:   27.8s
# [Parallel(n_jobs=-1)]: Done 39658 tasks      | elapsed:   27.9s
# [Parallel(n_jobs=-1)]: Done 39673 tasks      | elapsed:   27.9s
# [Parallel(n_jobs=-1)]: Done 39688 tasks      | elapsed:   27.9s
# [Parallel(n_jobs=-1)]: Done 39703 tasks      | elapsed:   27.9s
# [Parallel(n_jobs=-1)]: Done 39718 tasks      | elapsed:   28.0s
# [Parallel(n_jobs=-1)]: Done 39733 tasks      | elapsed:   28.0s
# [Parallel(n_jobs=-1)]: Done 39748 tasks      | elapsed:   28.0s
# [Parallel(n_jobs=-1)]: Done 39763 tasks      | elapsed:   28.1s
# [Parallel(n_jobs=-1)]: Done 39778 tasks      | elapsed:   28.1s
# [Parallel(n_jobs=-1)]: Done 39793 tasks      | elapsed:   28.1s
# [Parallel(n_jobs=-1)]: Done 39808 tasks      | elapsed:   28.1s
# [Parallel(n_jobs=-1)]: Done 39823 tasks      | elapsed:   28.1s
# [Parallel(n_jobs=-1)]: Done 39838 tasks      | elapsed:   28.2s
# [Parallel(n_jobs=-1)]: Done 39853 tasks      | elapsed:   28.3s
# [Parallel(n_jobs=-1)]: Done 39868 tasks      | elapsed:   28.5s
# [Parallel(n_jobs=-1)]: Done 39883 tasks      | elapsed:   28.5s
# [Parallel(n_jobs=-1)]: Done 39898 tasks      | elapsed:   28.5s
# [Parallel(n_jobs=-1)]: Done 39913 tasks      | elapsed:   28.5s
# [Parallel(n_jobs=-1)]: Done 39928 tasks      | elapsed:   28.5s
# [Parallel(n_jobs=-1)]: Done 39943 tasks      | elapsed:   28.5s
# [Parallel(n_jobs=-1)]: Done 39958 tasks      | elapsed:   28.5s
# [Parallel(n_jobs=-1)]: Done 39973 tasks      | elapsed:   28.6s
# [Parallel(n_jobs=-1)]: Done 39988 tasks      | elapsed:   28.6s
# [Parallel(n_jobs=-1)]: Done 40003 tasks      | elapsed:   28.6s
# [Parallel(n_jobs=-1)]: Done 40018 tasks      | elapsed:   28.6s
# [Parallel(n_jobs=-1)]: Done 40033 tasks      | elapsed:   28.6s
# [Parallel(n_jobs=-1)]: Done 40048 tasks      | elapsed:   28.7s
# [Parallel(n_jobs=-1)]: Done 40063 tasks      | elapsed:   28.7s
# [Parallel(n_jobs=-1)]: Done 40078 tasks      | elapsed:   28.8s
# [Parallel(n_jobs=-1)]: Done 40093 tasks      | elapsed:   28.8s
# [Parallel(n_jobs=-1)]: Done 40108 tasks      | elapsed:   28.8s
# [Parallel(n_jobs=-1)]: Done 40123 tasks      | elapsed:   28.8s
# [Parallel(n_jobs=-1)]: Done 40138 tasks      | elapsed:   28.8s
# [Parallel(n_jobs=-1)]: Done 40153 tasks      | elapsed:   28.9s
# [Parallel(n_jobs=-1)]: Done 40168 tasks      | elapsed:   28.9s
# [Parallel(n_jobs=-1)]: Done 40183 tasks      | elapsed:   28.9s
# [Parallel(n_jobs=-1)]: Done 40198 tasks      | elapsed:   28.9s
# [Parallel(n_jobs=-1)]: Done 40213 tasks      | elapsed:   29.0s
# [Parallel(n_jobs=-1)]: Done 40228 tasks      | elapsed:   29.0s
# [Parallel(n_jobs=-1)]: Done 40243 tasks      | elapsed:   29.0s
# [Parallel(n_jobs=-1)]: Done 40258 tasks      | elapsed:   29.0s
# [Parallel(n_jobs=-1)]: Done 40273 tasks      | elapsed:   29.0s
# [Parallel(n_jobs=-1)]: Done 40288 tasks      | elapsed:   29.0s
# [Parallel(n_jobs=-1)]: Done 40303 tasks      | elapsed:   29.0s
# [Parallel(n_jobs=-1)]: Done 40318 tasks      | elapsed:   29.1s
# [Parallel(n_jobs=-1)]: Done 40333 tasks      | elapsed:   29.1s
# [Parallel(n_jobs=-1)]: Done 40348 tasks      | elapsed:   29.1s
# [Parallel(n_jobs=-1)]: Done 40363 tasks      | elapsed:   29.2s
# [Parallel(n_jobs=-1)]: Done 40378 tasks      | elapsed:   29.2s
# [Parallel(n_jobs=-1)]: Done 40393 tasks      | elapsed:   29.2s
# [Parallel(n_jobs=-1)]: Done 40408 tasks      | elapsed:   29.2s
# [Parallel(n_jobs=-1)]: Done 40423 tasks      | elapsed:   29.3s
# [Parallel(n_jobs=-1)]: Done 40438 tasks      | elapsed:   29.3s
# [Parallel(n_jobs=-1)]: Done 40453 tasks      | elapsed:   29.3s
# [Parallel(n_jobs=-1)]: Done 40468 tasks      | elapsed:   29.3s
# [Parallel(n_jobs=-1)]: Done 40483 tasks      | elapsed:   29.4s
# [Parallel(n_jobs=-1)]: Done 40498 tasks      | elapsed:   29.4s
# [Parallel(n_jobs=-1)]: Done 40513 tasks      | elapsed:   29.4s
# [Parallel(n_jobs=-1)]: Done 40528 tasks      | elapsed:   29.4s
# [Parallel(n_jobs=-1)]: Done 40543 tasks      | elapsed:   29.5s
# [Parallel(n_jobs=-1)]: Done 40558 tasks      | elapsed:   29.5s
# [Parallel(n_jobs=-1)]: Done 40573 tasks      | elapsed:   29.5s
# [Parallel(n_jobs=-1)]: Done 40588 tasks      | elapsed:   29.5s
# [Parallel(n_jobs=-1)]: Done 40603 tasks      | elapsed:   29.5s
# [Parallel(n_jobs=-1)]: Done 40618 tasks      | elapsed:   29.5s
# [Parallel(n_jobs=-1)]: Done 40633 tasks      | elapsed:   29.6s
# [Parallel(n_jobs=-1)]: Done 40648 tasks      | elapsed:   29.6s
# [Parallel(n_jobs=-1)]: Done 40663 tasks      | elapsed:   29.6s
# [Parallel(n_jobs=-1)]: Done 40678 tasks      | elapsed:   29.7s
# [Parallel(n_jobs=-1)]: Done 40693 tasks      | elapsed:   29.7s
# [Parallel(n_jobs=-1)]: Done 40708 tasks      | elapsed:   29.7s
# [Parallel(n_jobs=-1)]: Done 40723 tasks      | elapsed:   29.7s
# [Parallel(n_jobs=-1)]: Done 40738 tasks      | elapsed:   29.7s
# [Parallel(n_jobs=-1)]: Done 40753 tasks      | elapsed:   29.8s
# [Parallel(n_jobs=-1)]: Done 40768 tasks      | elapsed:   29.8s
# [Parallel(n_jobs=-1)]: Done 40783 tasks      | elapsed:   29.8s
# [Parallel(n_jobs=-1)]: Done 40798 tasks      | elapsed:   29.8s
# [Parallel(n_jobs=-1)]: Done 40813 tasks      | elapsed:   29.8s
# [Parallel(n_jobs=-1)]: Done 40828 tasks      | elapsed:   29.9s
# [Parallel(n_jobs=-1)]: Done 40843 tasks      | elapsed:   29.9s
# [Parallel(n_jobs=-1)]: Done 40858 tasks      | elapsed:   29.9s
# [Parallel(n_jobs=-1)]: Done 40873 tasks      | elapsed:   29.9s
# [Parallel(n_jobs=-1)]: Done 40888 tasks      | elapsed:   29.9s
# [Parallel(n_jobs=-1)]: Done 40903 tasks      | elapsed:   30.0s
# [Parallel(n_jobs=-1)]: Done 40918 tasks      | elapsed:   30.0s
# [Parallel(n_jobs=-1)]: Done 40933 tasks      | elapsed:   30.0s
# [Parallel(n_jobs=-1)]: Done 40948 tasks      | elapsed:   30.0s
# [Parallel(n_jobs=-1)]: Done 40963 tasks      | elapsed:   30.0s
# [Parallel(n_jobs=-1)]: Done 40978 tasks      | elapsed:   30.0s
# [Parallel(n_jobs=-1)]: Done 40993 tasks      | elapsed:   30.1s
# [Parallel(n_jobs=-1)]: Done 41008 tasks      | elapsed:   30.1s
# [Parallel(n_jobs=-1)]: Done 41023 tasks      | elapsed:   30.1s
# [Parallel(n_jobs=-1)]: Done 41038 tasks      | elapsed:   30.2s
# [Parallel(n_jobs=-1)]: Done 41053 tasks      | elapsed:   30.2s
# [Parallel(n_jobs=-1)]: Done 41068 tasks      | elapsed:   30.2s
# [Parallel(n_jobs=-1)]: Done 41083 tasks      | elapsed:   30.3s
# [Parallel(n_jobs=-1)]: Done 41098 tasks      | elapsed:   30.3s
# [Parallel(n_jobs=-1)]: Done 41113 tasks      | elapsed:   30.3s
# [Parallel(n_jobs=-1)]: Done 41128 tasks      | elapsed:   30.3s
# [Parallel(n_jobs=-1)]: Done 41143 tasks      | elapsed:   30.3s
# [Parallel(n_jobs=-1)]: Done 41158 tasks      | elapsed:   30.3s
# [Parallel(n_jobs=-1)]: Done 41173 tasks      | elapsed:   30.4s
# [Parallel(n_jobs=-1)]: Done 41188 tasks      | elapsed:   30.4s
# [Parallel(n_jobs=-1)]: Done 41203 tasks      | elapsed:   30.4s
# [Parallel(n_jobs=-1)]: Done 41218 tasks      | elapsed:   30.4s
# [Parallel(n_jobs=-1)]: Done 41233 tasks      | elapsed:   30.5s
# [Parallel(n_jobs=-1)]: Done 41248 tasks      | elapsed:   30.5s
# [Parallel(n_jobs=-1)]: Done 41263 tasks      | elapsed:   30.5s
# [Parallel(n_jobs=-1)]: Done 41278 tasks      | elapsed:   30.5s
# [Parallel(n_jobs=-1)]: Done 41293 tasks      | elapsed:   30.6s
# [Parallel(n_jobs=-1)]: Done 41308 tasks      | elapsed:   30.6s
# [Parallel(n_jobs=-1)]: Done 41323 tasks      | elapsed:   30.6s
# [Parallel(n_jobs=-1)]: Done 41338 tasks      | elapsed:   30.6s
# [Parallel(n_jobs=-1)]: Done 41353 tasks      | elapsed:   30.6s
# [Parallel(n_jobs=-1)]: Done 41368 tasks      | elapsed:   30.7s
# [Parallel(n_jobs=-1)]: Done 41383 tasks      | elapsed:   30.7s
# [Parallel(n_jobs=-1)]: Done 41398 tasks      | elapsed:   30.8s
# [Parallel(n_jobs=-1)]: Done 41413 tasks      | elapsed:   30.8s
# [Parallel(n_jobs=-1)]: Done 41428 tasks      | elapsed:   30.8s
# [Parallel(n_jobs=-1)]: Done 41443 tasks      | elapsed:   30.9s
# [Parallel(n_jobs=-1)]: Done 41458 tasks      | elapsed:   30.9s
# [Parallel(n_jobs=-1)]: Done 41473 tasks      | elapsed:   30.9s
# [Parallel(n_jobs=-1)]: Done 41488 tasks      | elapsed:   30.9s
# [Parallel(n_jobs=-1)]: Done 41503 tasks      | elapsed:   30.9s
# [Parallel(n_jobs=-1)]: Done 41518 tasks      | elapsed:   30.9s
# [Parallel(n_jobs=-1)]: Done 41533 tasks      | elapsed:   30.9s
# [Parallel(n_jobs=-1)]: Done 41548 tasks      | elapsed:   30.9s
# [Parallel(n_jobs=-1)]: Done 41563 tasks      | elapsed:   31.0s
# [Parallel(n_jobs=-1)]: Done 41578 tasks      | elapsed:   31.0s
# [Parallel(n_jobs=-1)]: Done 41593 tasks      | elapsed:   31.0s
# [Parallel(n_jobs=-1)]: Done 41608 tasks      | elapsed:   31.0s
# [Parallel(n_jobs=-1)]: Done 41623 tasks      | elapsed:   31.0s
# [Parallel(n_jobs=-1)]: Done 41638 tasks      | elapsed:   31.1s
# [Parallel(n_jobs=-1)]: Done 41653 tasks      | elapsed:   31.1s
# [Parallel(n_jobs=-1)]: Done 41668 tasks      | elapsed:   31.1s
# [Parallel(n_jobs=-1)]: Done 41683 tasks      | elapsed:   31.1s
# [Parallel(n_jobs=-1)]: Done 41698 tasks      | elapsed:   31.2s
# [Parallel(n_jobs=-1)]: Done 41713 tasks      | elapsed:   31.2s
# [Parallel(n_jobs=-1)]: Done 41728 tasks      | elapsed:   31.2s
# [Parallel(n_jobs=-1)]: Done 41743 tasks      | elapsed:   31.2s
# [Parallel(n_jobs=-1)]: Done 41758 tasks      | elapsed:   31.3s
# [Parallel(n_jobs=-1)]: Done 41773 tasks      | elapsed:   31.3s
# [Parallel(n_jobs=-1)]: Done 41788 tasks      | elapsed:   31.3s
# [Parallel(n_jobs=-1)]: Done 41803 tasks      | elapsed:   31.4s
# [Parallel(n_jobs=-1)]: Done 41818 tasks      | elapsed:   31.4s
# [Parallel(n_jobs=-1)]: Done 41833 tasks      | elapsed:   31.4s
# [Parallel(n_jobs=-1)]: Done 41848 tasks      | elapsed:   31.4s
# [Parallel(n_jobs=-1)]: Done 41863 tasks      | elapsed:   31.4s
# [Parallel(n_jobs=-1)]: Done 41878 tasks      | elapsed:   31.5s
# [Parallel(n_jobs=-1)]: Done 41893 tasks      | elapsed:   31.5s
# [Parallel(n_jobs=-1)]: Done 41908 tasks      | elapsed:   31.5s
# [Parallel(n_jobs=-1)]: Done 41923 tasks      | elapsed:   31.5s
# [Parallel(n_jobs=-1)]: Done 41938 tasks      | elapsed:   31.5s
# [Parallel(n_jobs=-1)]: Done 41953 tasks      | elapsed:   31.5s
# [Parallel(n_jobs=-1)]: Done 41968 tasks      | elapsed:   31.6s
# [Parallel(n_jobs=-1)]: Done 41983 tasks      | elapsed:   31.6s
# [Parallel(n_jobs=-1)]: Done 41998 tasks      | elapsed:   31.6s
# [Parallel(n_jobs=-1)]: Done 42013 tasks      | elapsed:   31.6s
# [Parallel(n_jobs=-1)]: Done 42028 tasks      | elapsed:   31.7s
# [Parallel(n_jobs=-1)]: Done 42043 tasks      | elapsed:   31.7s
# [Parallel(n_jobs=-1)]: Done 42058 tasks      | elapsed:   31.7s
# [Parallel(n_jobs=-1)]: Done 42073 tasks      | elapsed:   31.8s
# [Parallel(n_jobs=-1)]: Done 42088 tasks      | elapsed:   31.8s
# [Parallel(n_jobs=-1)]: Done 42103 tasks      | elapsed:   31.9s
# [Parallel(n_jobs=-1)]: Done 42118 tasks      | elapsed:   31.9s
# [Parallel(n_jobs=-1)]: Done 42133 tasks      | elapsed:   31.9s
# [Parallel(n_jobs=-1)]: Done 42148 tasks      | elapsed:   31.9s
# [Parallel(n_jobs=-1)]: Done 42163 tasks      | elapsed:   31.9s
# [Parallel(n_jobs=-1)]: Done 42178 tasks      | elapsed:   32.0s
# [Parallel(n_jobs=-1)]: Done 42193 tasks      | elapsed:   32.0s
# [Parallel(n_jobs=-1)]: Done 42208 tasks      | elapsed:   32.0s
# [Parallel(n_jobs=-1)]: Done 42223 tasks      | elapsed:   32.0s
# [Parallel(n_jobs=-1)]: Done 42238 tasks      | elapsed:   32.0s
# [Parallel(n_jobs=-1)]: Done 42253 tasks      | elapsed:   32.0s
# [Parallel(n_jobs=-1)]: Done 42268 tasks      | elapsed:   32.1s
# [Parallel(n_jobs=-1)]: Done 42283 tasks      | elapsed:   32.1s
# [Parallel(n_jobs=-1)]: Done 42298 tasks      | elapsed:   32.1s
# [Parallel(n_jobs=-1)]: Done 42313 tasks      | elapsed:   32.2s
# [Parallel(n_jobs=-1)]: Done 42328 tasks      | elapsed:   32.2s
# [Parallel(n_jobs=-1)]: Done 42343 tasks      | elapsed:   32.2s
# [Parallel(n_jobs=-1)]: Done 42358 tasks      | elapsed:   32.2s
# [Parallel(n_jobs=-1)]: Done 42373 tasks      | elapsed:   32.3s
# [Parallel(n_jobs=-1)]: Done 42388 tasks      | elapsed:   32.3s
# [Parallel(n_jobs=-1)]: Done 42403 tasks      | elapsed:   32.3s
# [Parallel(n_jobs=-1)]: Done 42418 tasks      | elapsed:   32.3s
# [Parallel(n_jobs=-1)]: Done 42433 tasks      | elapsed:   32.4s
# [Parallel(n_jobs=-1)]: Done 42448 tasks      | elapsed:   32.4s
# [Parallel(n_jobs=-1)]: Done 42463 tasks      | elapsed:   32.4s
# [Parallel(n_jobs=-1)]: Done 42478 tasks      | elapsed:   32.4s
# [Parallel(n_jobs=-1)]: Done 42493 tasks      | elapsed:   32.5s
# [Parallel(n_jobs=-1)]: Done 42508 tasks      | elapsed:   32.5s
# [Parallel(n_jobs=-1)]: Done 42523 tasks      | elapsed:   32.6s
# [Parallel(n_jobs=-1)]: Done 42538 tasks      | elapsed:   32.6s
# [Parallel(n_jobs=-1)]: Done 42553 tasks      | elapsed:   32.6s
# [Parallel(n_jobs=-1)]: Done 42568 tasks      | elapsed:   32.6s
# [Parallel(n_jobs=-1)]: Done 42583 tasks      | elapsed:   32.6s
# [Parallel(n_jobs=-1)]: Done 42598 tasks      | elapsed:   32.6s
# [Parallel(n_jobs=-1)]: Done 42613 tasks      | elapsed:   32.7s
# [Parallel(n_jobs=-1)]: Done 42628 tasks      | elapsed:   32.7s
# [Parallel(n_jobs=-1)]: Done 42643 tasks      | elapsed:   32.7s
# [Parallel(n_jobs=-1)]: Done 42658 tasks      | elapsed:   32.8s
# [Parallel(n_jobs=-1)]: Done 42673 tasks      | elapsed:   32.8s
# [Parallel(n_jobs=-1)]: Done 42688 tasks      | elapsed:   32.8s
# [Parallel(n_jobs=-1)]: Done 42703 tasks      | elapsed:   32.8s
# [Parallel(n_jobs=-1)]: Done 42718 tasks      | elapsed:   32.9s
# [Parallel(n_jobs=-1)]: Done 42733 tasks      | elapsed:   32.9s
# [Parallel(n_jobs=-1)]: Done 42748 tasks      | elapsed:   32.9s
# [Parallel(n_jobs=-1)]: Done 42763 tasks      | elapsed:   32.9s
# [Parallel(n_jobs=-1)]: Done 42778 tasks      | elapsed:   32.9s
# [Parallel(n_jobs=-1)]: Done 42793 tasks      | elapsed:   33.0s
# [Parallel(n_jobs=-1)]: Done 42808 tasks      | elapsed:   33.0s
# [Parallel(n_jobs=-1)]: Done 42823 tasks      | elapsed:   33.0s
# [Parallel(n_jobs=-1)]: Done 42838 tasks      | elapsed:   33.0s
# [Parallel(n_jobs=-1)]: Done 42853 tasks      | elapsed:   33.1s
# [Parallel(n_jobs=-1)]: Done 42868 tasks      | elapsed:   33.1s
# [Parallel(n_jobs=-1)]: Done 42883 tasks      | elapsed:   33.1s
# [Parallel(n_jobs=-1)]: Done 42898 tasks      | elapsed:   33.1s
# [Parallel(n_jobs=-1)]: Done 42913 tasks      | elapsed:   33.3s
# [Parallel(n_jobs=-1)]: Done 42928 tasks      | elapsed:   33.3s
# [Parallel(n_jobs=-1)]: Done 42943 tasks      | elapsed:   33.3s
# [Parallel(n_jobs=-1)]: Done 42958 tasks      | elapsed:   33.4s
# [Parallel(n_jobs=-1)]: Done 42973 tasks      | elapsed:   33.4s
# [Parallel(n_jobs=-1)]: Done 42988 tasks      | elapsed:   33.4s
# [Parallel(n_jobs=-1)]: Done 43003 tasks      | elapsed:   33.4s
# [Parallel(n_jobs=-1)]: Done 43018 tasks      | elapsed:   33.4s
# [Parallel(n_jobs=-1)]: Done 43033 tasks      | elapsed:   33.4s
# [Parallel(n_jobs=-1)]: Done 43048 tasks      | elapsed:   33.4s
# [Parallel(n_jobs=-1)]: Done 43063 tasks      | elapsed:   33.5s
# [Parallel(n_jobs=-1)]: Done 43078 tasks      | elapsed:   33.5s
# [Parallel(n_jobs=-1)]: Done 43093 tasks      | elapsed:   33.5s
# [Parallel(n_jobs=-1)]: Done 43108 tasks      | elapsed:   33.5s
# [Parallel(n_jobs=-1)]: Done 43123 tasks      | elapsed:   33.6s
# [Parallel(n_jobs=-1)]: Done 43138 tasks      | elapsed:   33.6s
# [Parallel(n_jobs=-1)]: Done 43153 tasks      | elapsed:   33.6s
# [Parallel(n_jobs=-1)]: Done 43168 tasks      | elapsed:   33.6s
# [Parallel(n_jobs=-1)]: Done 43183 tasks      | elapsed:   33.7s
# [Parallel(n_jobs=-1)]: Done 43198 tasks      | elapsed:   33.7s
# [Parallel(n_jobs=-1)]: Done 43213 tasks      | elapsed:   33.7s
# [Parallel(n_jobs=-1)]: Done 43228 tasks      | elapsed:   33.7s
# [Parallel(n_jobs=-1)]: Done 43243 tasks      | elapsed:   33.7s
# [Parallel(n_jobs=-1)]: Done 43258 tasks      | elapsed:   33.8s
# [Parallel(n_jobs=-1)]: Done 43273 tasks      | elapsed:   33.8s
# [Parallel(n_jobs=-1)]: Done 43288 tasks      | elapsed:   33.8s
# [Parallel(n_jobs=-1)]: Done 43303 tasks      | elapsed:   33.8s
# [Parallel(n_jobs=-1)]: Done 43318 tasks      | elapsed:   33.9s
# [Parallel(n_jobs=-1)]: Done 43333 tasks      | elapsed:   33.9s
# [Parallel(n_jobs=-1)]: Done 43348 tasks      | elapsed:   33.9s
# [Parallel(n_jobs=-1)]: Done 43363 tasks      | elapsed:   33.9s
# [Parallel(n_jobs=-1)]: Done 43378 tasks      | elapsed:   33.9s
# [Parallel(n_jobs=-1)]: Done 43393 tasks      | elapsed:   34.0s
# [Parallel(n_jobs=-1)]: Done 43408 tasks      | elapsed:   34.0s
# [Parallel(n_jobs=-1)]: Done 43423 tasks      | elapsed:   34.0s
# [Parallel(n_jobs=-1)]: Done 43438 tasks      | elapsed:   34.0s
# [Parallel(n_jobs=-1)]: Done 43453 tasks      | elapsed:   34.1s
# [Parallel(n_jobs=-1)]: Done 43468 tasks      | elapsed:   34.1s
# [Parallel(n_jobs=-1)]: Done 43483 tasks      | elapsed:   34.2s
# [Parallel(n_jobs=-1)]: Done 43498 tasks      | elapsed:   34.2s
# [Parallel(n_jobs=-1)]: Done 43513 tasks      | elapsed:   34.2s
# [Parallel(n_jobs=-1)]: Done 43528 tasks      | elapsed:   34.2s
# [Parallel(n_jobs=-1)]: Done 43543 tasks      | elapsed:   34.2s
# [Parallel(n_jobs=-1)]: Done 43558 tasks      | elapsed:   34.2s
# [Parallel(n_jobs=-1)]: Done 43573 tasks      | elapsed:   34.2s
# [Parallel(n_jobs=-1)]: Done 43588 tasks      | elapsed:   34.3s
# [Parallel(n_jobs=-1)]: Done 43603 tasks      | elapsed:   34.3s
# [Parallel(n_jobs=-1)]: Done 43618 tasks      | elapsed:   34.3s
# [Parallel(n_jobs=-1)]: Done 43633 tasks      | elapsed:   34.3s
# [Parallel(n_jobs=-1)]: Done 43648 tasks      | elapsed:   34.3s
# [Parallel(n_jobs=-1)]: Done 43663 tasks      | elapsed:   34.4s
# [Parallel(n_jobs=-1)]: Done 43678 tasks      | elapsed:   34.4s
# [Parallel(n_jobs=-1)]: Done 43693 tasks      | elapsed:   34.4s
# [Parallel(n_jobs=-1)]: Done 43708 tasks      | elapsed:   34.4s
# [Parallel(n_jobs=-1)]: Done 43723 tasks      | elapsed:   34.5s
# [Parallel(n_jobs=-1)]: Done 43738 tasks      | elapsed:   34.5s
# [Parallel(n_jobs=-1)]: Done 43753 tasks      | elapsed:   34.5s
# [Parallel(n_jobs=-1)]: Done 43768 tasks      | elapsed:   34.5s
# [Parallel(n_jobs=-1)]: Done 43783 tasks      | elapsed:   34.6s
# [Parallel(n_jobs=-1)]: Done 43798 tasks      | elapsed:   34.6s
# [Parallel(n_jobs=-1)]: Done 43813 tasks      | elapsed:   34.6s
# [Parallel(n_jobs=-1)]: Done 43828 tasks      | elapsed:   34.7s
# [Parallel(n_jobs=-1)]: Done 43843 tasks      | elapsed:   34.7s
# [Parallel(n_jobs=-1)]: Done 43858 tasks      | elapsed:   34.7s
# [Parallel(n_jobs=-1)]: Done 43873 tasks      | elapsed:   34.7s
# [Parallel(n_jobs=-1)]: Done 43888 tasks      | elapsed:   34.8s
# [Parallel(n_jobs=-1)]: Done 43903 tasks      | elapsed:   34.8s
# [Parallel(n_jobs=-1)]: Done 43918 tasks      | elapsed:   34.8s
# [Parallel(n_jobs=-1)]: Done 43933 tasks      | elapsed:   34.8s
# [Parallel(n_jobs=-1)]: Done 43948 tasks      | elapsed:   34.8s
# [Parallel(n_jobs=-1)]: Done 43963 tasks      | elapsed:   34.8s
# [Parallel(n_jobs=-1)]: Done 43978 tasks      | elapsed:   34.8s
# [Parallel(n_jobs=-1)]: Done 43993 tasks      | elapsed:   34.8s
# [Parallel(n_jobs=-1)]: Done 44008 tasks      | elapsed:   34.8s
# [Parallel(n_jobs=-1)]: Done 44023 tasks      | elapsed:   34.9s
# [Parallel(n_jobs=-1)]: Done 44038 tasks      | elapsed:   34.9s
# [Parallel(n_jobs=-1)]: Done 44053 tasks      | elapsed:   34.9s
# [Parallel(n_jobs=-1)]: Done 44068 tasks      | elapsed:   35.0s
# [Parallel(n_jobs=-1)]: Done 44083 tasks      | elapsed:   35.0s
# [Parallel(n_jobs=-1)]: Done 44098 tasks      | elapsed:   35.0s
# [Parallel(n_jobs=-1)]: Done 44113 tasks      | elapsed:   35.1s
# [Parallel(n_jobs=-1)]: Done 44128 tasks      | elapsed:   35.1s
# [Parallel(n_jobs=-1)]: Done 44143 tasks      | elapsed:   35.1s
# [Parallel(n_jobs=-1)]: Done 44158 tasks      | elapsed:   35.1s
# [Parallel(n_jobs=-1)]: Done 44173 tasks      | elapsed:   35.2s
# [Parallel(n_jobs=-1)]: Done 44188 tasks      | elapsed:   35.2s
# [Parallel(n_jobs=-1)]: Done 44203 tasks      | elapsed:   35.2s
# [Parallel(n_jobs=-1)]: Done 44218 tasks      | elapsed:   35.2s
# [Parallel(n_jobs=-1)]: Done 44233 tasks      | elapsed:   35.2s
# [Parallel(n_jobs=-1)]: Done 44248 tasks      | elapsed:   35.3s
# [Parallel(n_jobs=-1)]: Done 44263 tasks      | elapsed:   35.3s
# [Parallel(n_jobs=-1)]: Done 44278 tasks      | elapsed:   35.3s
# [Parallel(n_jobs=-1)]: Done 44293 tasks      | elapsed:   35.3s
# [Parallel(n_jobs=-1)]: Done 44308 tasks      | elapsed:   35.4s
# [Parallel(n_jobs=-1)]: Done 44323 tasks      | elapsed:   35.4s
# [Parallel(n_jobs=-1)]: Done 44338 tasks      | elapsed:   35.4s
# [Parallel(n_jobs=-1)]: Done 44353 tasks      | elapsed:   35.5s
# [Parallel(n_jobs=-1)]: Done 44368 tasks      | elapsed:   35.5s
# [Parallel(n_jobs=-1)]: Done 44383 tasks      | elapsed:   35.5s
# [Parallel(n_jobs=-1)]: Done 44398 tasks      | elapsed:   35.5s
# [Parallel(n_jobs=-1)]: Done 44413 tasks      | elapsed:   35.5s
# [Parallel(n_jobs=-1)]: Done 44428 tasks      | elapsed:   35.5s
# [Parallel(n_jobs=-1)]: Done 44443 tasks      | elapsed:   35.5s
# [Parallel(n_jobs=-1)]: Done 44458 tasks      | elapsed:   35.6s
# [Parallel(n_jobs=-1)]: Done 44473 tasks      | elapsed:   35.6s
# [Parallel(n_jobs=-1)]: Done 44488 tasks      | elapsed:   35.6s
# [Parallel(n_jobs=-1)]: Done 44503 tasks      | elapsed:   35.7s
# [Parallel(n_jobs=-1)]: Done 44518 tasks      | elapsed:   35.7s
# [Parallel(n_jobs=-1)]: Done 44533 tasks      | elapsed:   35.7s
# [Parallel(n_jobs=-1)]: Done 44548 tasks      | elapsed:   35.7s
# [Parallel(n_jobs=-1)]: Done 44563 tasks      | elapsed:   35.8s
# [Parallel(n_jobs=-1)]: Done 44578 tasks      | elapsed:   35.8s
# ...
# [Parallel(n_jobs=-1)]: Done 69383 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69390 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69397 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69404 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69411 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69418 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69425 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69432 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69439 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69446 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69453 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69460 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69467 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69474 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69481 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69488 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69495 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69502 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69509 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69516 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69523 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69530 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69537 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69544 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69551 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69558 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69565 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69572 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69579 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69586 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69593 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69600 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69607 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69614 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69621 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69628 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69635 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1966s.) Setting batch_size=14.
# [Parallel(n_jobs=-1)]: Done 69642 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69649 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69656 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69663 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69670 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69677 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69684 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69691 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69698 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69705 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69712 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69719 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69726 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69733 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69740 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69747 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69754 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69761 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69768 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69775 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69782 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69789 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69796 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69803 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69810 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69817 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69824 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69831 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69838 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69845 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69852 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69866 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69880 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69894 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69908 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69922 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69936 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69950 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69964 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69978 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 69992 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70006 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70020 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70034 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70048 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70062 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70076 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70090 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70104 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70118 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70132 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70146 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70160 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70174 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70188 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70202 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70216 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70230 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70244 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70258 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70272 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70286 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70300 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70314 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70328 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70342 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70356 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70370 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70384 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70398 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70412 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70426 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70440 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70454 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70468 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70482 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70496 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70510 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70524 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70538 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70552 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70566 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70580 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70594 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70608 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70622 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70636 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70650 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70664 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70678 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70692 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70706 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70720 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70734 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70748 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70762 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70776 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70790 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70804 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70818 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70832 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70846 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70860 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70874 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70888 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70902 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70916 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70930 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70944 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70958 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70972 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 70986 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71000 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71014 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71028 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71042 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71056 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71070 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71084 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71098 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71112 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71126 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71140 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71154 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71168 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71182 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71196 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71210 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71224 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71238 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71252 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71266 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71280 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71294 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71308 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71322 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71336 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71350 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71364 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71378 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71392 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71406 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71420 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71434 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71448 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71462 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71476 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71490 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71504 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71518 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71532 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71546 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71560 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71574 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71588 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71602 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71616 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71630 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71644 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71658 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71672 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71686 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71700 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71714 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71728 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71742 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71756 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71770 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71784 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71798 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71812 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71826 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71840 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71854 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71868 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71882 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71896 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71910 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71924 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71938 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71952 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71966 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71980 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 71994 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 72008 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 72022 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 72036 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 72050 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 72064 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 72078 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 72092 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 72106 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 72120 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 72134 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 72148 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 72162 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 72176 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 72190 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 72204 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 72218 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 72232 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 72246 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 72260 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 72274 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 72288 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 72302 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 72316 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 72330 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 72344 tasks      | elapsed:  1.3min
# 100%|██████████| 72776/72776 [00:00<00:00, 440487.56it/s]
# [Parallel(n_jobs=-1)]: Done 72776 out of 72776 | elapsed:  1.4min finished

# %%
labels_agg = labels_df.groupby(["PetID", "description"])["score"].max().reset_index()
df2ffm.add_field_dataframe(labels_agg.rename(columns={"description": "labels_description"}).reset_index(), "labels_description", "score")
# Out:
# 274706it [00:26, 10359.27it/s]

# %%
ffm_df = pd.Series(df2ffm.result).reset_index()
ffm_df.columns = ["PetID", "ffm_text"]

train_ffm = train_df[["PetID", "AdoptionSpeed", "group"]].merge(ffm_df,
                                                                on="PetID",
                                                                how="left")

test_ffm = test_df[["PetID"]].merge(ffm_df,
                                    on="PetID",
                                    how="left")

# %%
train_ffm.head()
# Out:
#        PetID  AdoptionSpeed  group  \
# 0  86e1089a3              2      7
# 1  6296e909a              0      3
# 2  3422e4906              3      0
# 3  5842f1ff5              2      6
# 4  850a43f90              2      5
#
#                                             ffm_text
# 0  2 0:0:2 1:1:-0.39081823392891024 202:201:1 203...
# 1  0 0:0:2 1:1:-1.0702815346644163 202:202:1 203:...
# 2  3 0:0:1 1:1:-1.0702815346644163 202:203:1 203:...
# 3  2 0:0:1 1:1:-0.1720799079772499 202:203:1 203:...
# 4  2 0:0:1 1:1:-1.0702815346644163 202:203:1 203:...

# %%
with open("./working/test.txt", "w") as f:
    f.write("\n".join(test_ffm.loc[:, "ffm_text"].values.tolist()))

# %%
train_oof = np.zeros(len(train_df))
test_pred = np.zeros(len(test_df))

for j in tqdm(range(50)):
    i = j%10
    with open("./working/dev.txt", "w") as f:
        f.write("\n".join(train_ffm.loc[train_ffm["group"] != i, "ffm_text"].values.tolist()))
    with open("./working/val.txt", "w") as f:
        f.write("\n".join(train_ffm.loc[train_ffm["group"] == i, "ffm_text"].values.tolist()))
    param = {"task": "reg",
             "lr": .1,
             "epoch": 200,
             "lambda": .0001,
             "k": 4,
             "nthread": 4,
             "metric": "rmse"}
    ffm_model =xl.create_ffm()
    ffm_model.setTrain("./working/dev.txt")
    ffm_model.setValidate("./working/val.txt")
    ffm_model.fit(param, "./working/model.out")

    ffm_model.setTest("./working/val.txt")
    ffm_model.predict("./working/model.out", "./working/output.txt")
    output = pd.read_csv("./working/output.txt", header=None)[0].values
    train_oof[np.where(train_ffm["group"] == i)] += output / 5

    ffm_model.setTest("./working/test.txt")
    ffm_model.predict("./working/model.out", "./working/output.txt")
    output = pd.read_csv("./working/output.txt", header=None)[0].values
    test_pred += output / 50
# Out:
# 100%|██████████| 50/50 [02:27<00:00,  2.05s/it]

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(train_df["AdoptionSpeed"], train_oof))
# Out:
# 1.0623204592256668

# %%
from sklearn.metrics import cohen_kappa_score

# https://www.kaggle.com/naveenasaithambi/optimizedrounder-improved
class OptimizedRounder(object):
    def __init__(self):
        self.coef_ = 0
    
    def _kappa_loss(self, coef, X, y):
        preds = pd.cut(X, [-np.inf] + list(np.sort(coef)) + [np.inf], labels = [0, 1, 2, 3, 4])
        return -cohen_kappa_score(y, preds, weights = 'quadratic')
    
    def fit(self, X, y):
        loss_partial = partial(self._kappa_loss, X = X, y = y)
        initial_coef = np.percentile(X, [2.73, 23.3, 50.3, 72]) # <= improved
        self.coef_ = sp.optimize.minimize(loss_partial, initial_coef, method = 'nelder-mead')
    
    def predict(self, X, coef):
        preds = pd.cut(X, [-np.inf] + list(np.sort(coef)) + [np.inf], labels = [0, 1, 2, 3, 4])
        return preds
    
    def coefficients(self):
        return self.coef_['x']


# https://www.kaggle.com/c/petfinder-adoption-prediction/discussion/76106
def confusion_matrix(rater_a, rater_b, min_rating=None, max_rating=None):
    """
    Returns the confusion matrix between rater's ratings
    """
    assert(len(rater_a) == len(rater_b))
    if min_rating is None:
        min_rating = min(rater_a + rater_b)
    if max_rating is None:
        max_rating = max(rater_a + rater_b)
    num_ratings = int(max_rating - min_rating + 1)
    conf_mat = [[0 for i in range(num_ratings)]
                for j in range(num_ratings)]
    for a, b in zip(rater_a, rater_b):
        conf_mat[a - min_rating][b - min_rating] += 1
    return conf_mat


def histogram(ratings, min_rating=None, max_rating=None):
    """
    Returns the counts of each type of rating that a rater made
    """
    if min_rating is None:
        min_rating = min(ratings)
    if max_rating is None:
        max_rating = max(ratings)
    num_ratings = int(max_rating - min_rating + 1)
    hist_ratings = [0 for x in range(num_ratings)]
    for r in ratings:
        hist_ratings[r - min_rating] += 1
    return hist_ratings


def quadratic_weighted_kappa(y, y_pred):
    """
    Calculates the quadratic weighted kappa
    axquadratic_weighted_kappa calculates the quadratic weighted kappa
    value, which is a measure of inter-rater agreement between two raters
    that provide discrete numeric ratings.  Potential values range from -1
    (representing complete disagreement) to 1 (representing complete
    agreement).  A kappa value of 0 is expected if all agreement is due to
    chance.
    quadratic_weighted_kappa(rater_a, rater_b), where rater_a and rater_b
    each correspond to a list of integer ratings.  These lists must have the
    same length.
    The ratings should be integers, and it is assumed that they contain
    the complete range of possible ratings.
    quadratic_weighted_kappa(X, min_rating, max_rating), where min_rating
    is the minimum possible rating, and max_rating is the maximum possible
    rating
    """
    rater_a = y
    rater_b = y_pred
    min_rating=None
    max_rating=None
    rater_a = np.array(rater_a, dtype=int)
    rater_b = np.array(rater_b, dtype=int)
    assert(len(rater_a) == len(rater_b))
    if min_rating is None:
        min_rating = min(min(rater_a), min(rater_b))
    if max_rating is None:
        max_rating = max(max(rater_a), max(rater_b))
    conf_mat = confusion_matrix(rater_a, rater_b,
                                min_rating, max_rating)
    num_ratings = len(conf_mat)
    num_scored_items = float(len(rater_a))

    hist_rater_a = histogram(rater_a, min_rating, max_rating)
    hist_rater_b = histogram(rater_b, min_rating, max_rating)

    numerator = 0.0
    denominator = 0.0

    for i in range(num_ratings):
        for j in range(num_ratings):
            expected_count = (hist_rater_a[i] * hist_rater_b[j]
                              / num_scored_items)
            d = pow(i - j, 2.0) / pow(num_ratings - 1, 2.0)
            numerator += d * conf_mat[i][j] / num_scored_items
            denominator += d * expected_count / num_scored_items

    return (1.0 - numerator / denominator)

# %%
y_train = train_df["AdoptionSpeed"].values
group = train_df["group"].values

coef_mean = np.zeros(4)
for fold in range(10):
    dev_idx = np.where(group != fold)[0]
    val_idx = np.where(group == fold)[0]

    pred_dev = train_oof[dev_idx]
    y_dev = y_train[dev_idx]

    pred_val = train_oof[val_idx]
    y_val = y_train[val_idx]

    optR = OptimizedRounder()
    optR.fit(pred_dev, y_dev)
    coefficients = optR.coefficients()
    coef_mean += coefficients / 10
    pred_val_k = optR.predict(pred_val, coefficients)

# %%
quadratic_weighted_kappa(y_train, optR.predict(train_oof, coef_mean))
# Out:
# 0.41893563186692717

# %%
smpsb_df["AdoptionSpeed"] = optR.predict(test_pred, coef_mean)
smpsb_df.to_csv("submission.csv", index=None)
